# %%
import numpy as np
from astropy.io import fits
import os
from pathlib import Path
import copy
import shutil
from importlib import reload

import matplotlib.pyplot as plt

import falco
import proper

import misc

import hlc_band1_custom_config as config
reload(config)

output_dir = Path('/home/u21/kianmilani/src/pyfalco/data/brief/')

flatmaps_dir = Path('/home/u21/kianmilani/Documents/falco-roman-cgi-dark-holes/flatmaps')
dm1_design = fits.getdata(flatmaps_dir/'dm1_m_design_hlc_band1.fits')
dm2_design = fits.getdata(flatmaps_dir/'dm2_m_design_hlc_band1.fits')
dm1_flatmap = fits.getdata(flatmaps_dir/'dm1_m_flat_hlc_band1.fits')
dm2_flatmap = fits.getdata(flatmaps_dir/'dm2_m_flat_hlc_band1.fits')

# %%
reload(config)

mp = config.setup(N_subpass=1, N_waves_per_subpass=1, fractional_bandwidth=0.01,
                  estimator='perfect', 
                  N_iterations=5,
                  spatial_weighting=[],
                  dark_hole_sides='lr',
#                   dm1_initial=dm1_flatmap, dm2_initial=dm2_flatmap,
                  dm1_initial=dm1_flatmap+dm1_design, dm2_initial=dm2_flatmap+dm2_design,
                  label='',)

misc.myimshow2(mp.full.dm1.flatmap, mp.full.dm2.flatmap)
# Out:
# /home/u21/kianmilani/src/pyfalco/falco/config

# %%
reload(config)

config.perform_phase_retrieval(mp, quiet=True)
# Out:
# Performing retrieval for sub-bandpass 1.
#
# Getting aberrations from full optical train.
#
# Using pinhole at FPM to get back-end aberrations.
# Phase retrieval complete.

# %% [markdown]
# # Setup the workspace

# %%
# setup the workspace
out = falco.setup.flesh_out_workspace(mp)
# Out:
#  Using 1 discrete wavelength(s) in each of 1 sub-bandpasses over a 1.0% total bandpass
#
# Sub-bandpasses are centered at wavelengths [nm]:	 [575.]
#   Influence function padded from 84 to 84 points for A.S. propagation.
# Computing datacube of DM influence functions... done.
#   Influence function padded from 84 to 84 points for A.S. propagation.
# Computing datacube of DM influence functions... done.
# Beginning Trial 1 of Series 1.
#
# DM 1-to-2 Fresnel number (using radius) = 932.0391304347827

# %% [markdown]
# # Perform the Wavefront Sensing and Control

# %%
falco.wfsc.loop(mp, out)
# Out:
# Iteration: 0 / 4
# DMs to be used in this iteration = [ 1 2 ]
# Core throughput within the half-max isophote(s) = 4.64% 	at separation = (7.0, 0.0) lambda0/D.
# Zernike modes (Noll indexing) used in this Jacobian:	[1]
# Computing control Jacobian matrices in serial:
#   mode0dm1...mode0dm2...done.
# Elapsed: 46.010639905929565
# Weeding out weak actuators from the control Jacobian...
#   DM1: 1770/2304 (76.82%) actuators kept for Jacobian
#   DM2: 1783/2304 (77.39%) actuators kept for Jacobian
# Using the Jacobian to make other matrices...done.
# Control beginning ...
# Scaling factor:	1.00		1.00		1.00		1.00		1.00		1.00		1.00		1.00
# log10reg:    	-6.0		-5.5		-5.0		-4.5		-4.0		-3.5		-3.0		-2.5
# Inorm:       	5.30e-05	1.15e-05	2.29e-06	4.15e-07	1.27e-07	8.67e-08	7.62e-08	7.50e-08
# Model-based grid search expects log10reg, = -2.5,	 dmfac = 1.00,	 7.50e-08 normalized intensity.
#  DM1 P-V in volts: 11.575
#  DM2 P-V in volts: 13.278
# RMS surface of DM1 = 1.1 nm
# RMS surface of DM2 = 1.2 nm
# [Getting updated summed image]	Elapsed: 13.85806131362915
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/_snippet.pkl
# done.
# Itr:  0
# Prev and New Measured Normalized Intensity:			 1.61e-05	->	1.18e-06	 (13.60 x smaller)
#
#
# Iteration: 1 / 4
# DMs to be used in this iteration = [ 1 2 ]
# Core throughput within the half-max isophote(s) = 4.65% 	at separation = (7.0, 0.0) lambda0/D.
# Zernike modes (Noll indexing) used in this Jacobian:	[1]
# Computing control Jacobian matrices in serial:
#   mode0dm1...mode0dm2...done.
# Elapsed: 35.6185348033905
# Using the Jacobian to make other matrices...done.
# Control beginning ...
# Scaling factor:	1.00		1.00		1.00		1.00		1.00		1.00		1.00		1.00
# log10reg:    	-6.0		-5.5		-5.0		-4.5		-4.0		-3.5		-3.0		-2.5
# Inorm:       	5.81e-07	1.06e-07	3.08e-08	1.55e-08	8.96e-09	5.92e-09	5.91e-09	8.34e-09
# Model-based grid search expects log10reg, = -3.0,	 dmfac = 1.00,	 5.91e-09 normalized intensity.
#  DM1 P-V in volts: 13.400
#  DM2 P-V in volts: 14.504
# RMS surface of DM1 = 1.2 nm
# RMS surface of DM2 = 1.2 nm
# [Getting updated summed image]	Elapsed: 13.410540580749512
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/_snippet.pkl
# done.
# Itr:  1
# Prev and New Measured Normalized Intensity:			 1.18e-06	->	1.28e-07	 (9.25 x smaller)
#
#
# Iteration: 2 / 4
# DMs to be used in this iteration = [ 1 2 ]
# Core throughput within the half-max isophote(s) = 4.62% 	at separation = (7.0, 0.0) lambda0/D.
# Zernike modes (Noll indexing) used in this Jacobian:	[1]
# Computing control Jacobian matrices in serial:
#   mode0dm1...mode0dm2...done.
# Elapsed: 36.79899454116821
# Using the Jacobian to make other matrices...done.
# Control beginning ...
# Scaling factor:	1.00		1.00		1.00		1.00		1.00		1.00		1.00		1.00
# log10reg:    	-6.0		-5.5		-5.0		-4.5		-4.0		-3.5		-3.0		-2.5
# Inorm:       	2.77e-08	8.28e-09	2.65e-09	1.20e-09	8.33e-10	9.12e-10	1.36e-09	2.12e-09
# Model-based grid search expects log10reg, = -4.0,	 dmfac = 1.00,	 8.33e-10 normalized intensity.
#  DM1 P-V in volts: 14.803
#  DM2 P-V in volts: 15.042
# RMS surface of DM1 = 1.3 nm
# RMS surface of DM2 = 1.3 nm
# [Getting updated summed image]	Elapsed: 13.580313205718994
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/_snippet.pkl
# done.
# Itr:  2
# Prev and New Measured Normalized Intensity:			 1.28e-07	->	3.16e-08	 (4.06 x smaller)
#
#
# Iteration: 3 / 4
# DMs to be used in this iteration = [ 1 2 ]
# Core throughput within the half-max isophote(s) = 4.62% 	at separation = (7.0, 0.0) lambda0/D.
# Zernike modes (Noll indexing) used in this Jacobian:	[1]
# Computing control Jacobian matrices in serial:
#   mode0dm1...mode0dm2...done.
# Elapsed: 36.89339232444763
# Using the Jacobian to make other matrices...done.
# Control beginning ...
# Scaling factor:	1.00		1.00		1.00		1.00		1.00		1.00		1.00		1.00
# log10reg:    	-6.0		-5.5		-5.0		-4.5		-4.0		-3.5		-3.0		-2.5
# Inorm:       	5.15e-09	1.46e-09	4.45e-10	2.47e-10	2.58e-10	3.19e-10	4.05e-10	5.31e-10
# Model-based grid search expects log10reg, = -4.5,	 dmfac = 1.00,	 2.47e-10 normalized intensity.
#  DM1 P-V in volts: 15.290
#  DM2 P-V in volts: 17.681
# RMS surface of DM1 = 1.4 nm
# RMS surface of DM2 = 1.4 nm
# [Getting updated summed image]	Elapsed: 13.34918737411499
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/_snippet.pkl
# done.
# Itr:  3
# Prev and New Measured Normalized Intensity:			 3.16e-08	->	1.10e-08	 (2.86 x smaller)
#
#
# Iteration: 4 / 4
# DMs to be used in this iteration = [ 1 2 ]
# Core throughput within the half-max isophote(s) = 4.61% 	at separation = (7.0, 0.0) lambda0/D.
# Zernike modes (Noll indexing) used in this Jacobian:	[1]
# Computing control Jacobian matrices in serial:
#   mode0dm1...mode0dm2...done.
# Elapsed: 35.7832465171814
# Using the Jacobian to make other matrices...done.
# Control beginning ...
# Scaling factor:	1.00		1.00		1.00		1.00		1.00		1.00		1.00		1.00
# log10reg:    	-6.0		-5.5		-5.0		-4.5		-4.0		-3.5		-3.0		-2.5
# Inorm:       	2.17e-09	4.45e-10	1.69e-10	1.39e-10	1.54e-10	1.70e-10	1.86e-10	2.11e-10
# Model-based grid search expects log10reg, = -4.5,	 dmfac = 1.00,	 1.39e-10 normalized intensity.
#  DM1 P-V in volts: 15.577
#  DM2 P-V in volts: 18.974
# RMS surface of DM1 = 1.4 nm
# RMS surface of DM2 = 1.4 nm
# [Getting updated summed image]	Elapsed: 13.514566659927368
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/_snippet.pkl
# done.
# Itr:  4
# Prev and New Measured Normalized Intensity:			 1.10e-08	->	3.31e-09	 (3.33 x smaller)
#
#
# Core throughput within the half-max isophote(s) = 4.60% 	at separation = (7.0, 0.0) lambda0/D.
#
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/_snippet.pkl
# done.
#
# Entire workspace NOT saved because mp.flagSaveWS==False
# *** END OF WFSC LOOP ***

# %%
# Load results and plot the output data from pickled data
output_fname = output_dir/(mp.runLabel+'_snippet.pkl')
falco.plot.plot_trial_output_from_pickle(str(output_fname))
