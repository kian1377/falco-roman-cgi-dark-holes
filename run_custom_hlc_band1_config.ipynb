# %%
import numpy as np
from astropy.io import fits
import os
from pathlib import Path
import copy
import shutil
from importlib import reload

import matplotlib.pyplot as plt

import falco
import proper

import misc

import hlc_band1_custom_config as config
reload(config)

output_dir = Path('/home/u21/kianmilani/src/pyfalco/data/brief/')

flatmaps_dir = Path('/home/u21/kianmilani/Documents/falco-roman-cgi-dark-holes/flatmaps')
dm1_design = fits.getdata(flatmaps_dir/'dm1_m_design_hlc_band1.fits')
dm2_design = fits.getdata(flatmaps_dir/'dm2_m_design_hlc_band1.fits')
dm1_flatmap = fits.getdata(flatmaps_dir/'dm1_m_flat_hlc_band1.fits')
dm2_flatmap = fits.getdata(flatmaps_dir/'dm2_m_flat_hlc_band1.fits')

# %%
proper

# %%
reload(config)

mp = config.setup(N_subpass=1, N_waves_per_subpass=1, fractional_bandwidth=0.01,
                  estimator='perfect', 
                  N_iterations=5,
                  spatial_weighting=[],
                  dark_hole_sides='r',
#                   dm1_initial=dm1_flatmap, dm2_initial=dm2_flatmap,
                  dm1_initial=dm1_flatmap+dm1_design, dm2_initial=dm2_flatmap+dm2_design,
                  label='hlc_band1_perfect_bw0.1_r_design')

misc.myimshow2(mp.full.dm1.flatmap, mp.full.dm2.flatmap)
# Out:
# /home/u21/kianmilani/src/pyfalco/falco/config

# %%
reload(config)

config.perform_phase_retrieval(mp, quiet=True)
# Out:
# Performing retrieval for sub-bandpass 1.
#
# Getting aberrations from full optical train.
#
# Using pinhole at FPM to get back-end aberrations.

# %% [markdown]
# # Setup the workspace

# %%
# setup the workspace
out = falco.setup.flesh_out_workspace(mp)

# %% [markdown]
# # Perform the Wavefront Sensing and Control

# %%
falco.wfsc.loop(mp, out)
# Out:
# DMs to be used in this iteration = [ 1 2 ]
# Core throughput within the half-max isophote(s) = 4.64% 	at separation = (7.0, 0.0) lambda0/D.
# Zernike modes (Noll indexing) used in this Jacobian:	[1]
# Computing control Jacobian matrices in serial:
#   mode0dm1...mode0dm2...done.
# Elapsed: 45.08364677429199
# Weeding out weak actuators from the control Jacobian...
#   DM1: 1766/2304 (76.65%) actuators kept for Jacobian
#   DM2: 1791/2304 (77.73%) actuators kept for Jacobian
# Using the Jacobian to make other matrices...done.
# Control beginning ...
# Scaling factor:	1.00		1.00		1.00		1.00		1.00		1.00		1.00		1.00
# log10reg:    	-6.0		-5.5		-5.0		-4.5		-4.0		-3.5		-3.0		-2.5
# Inorm:       	6.25e-05	1.07e-05	1.65e-06	3.03e-07	9.99e-08	5.38e-08	4.34e-08	4.66e-08
# Model-based grid search expects log10reg, = -3.0,	 dmfac = 1.00,	 4.34e-08 normalized intensity.
#  DM1 P-V in volts: 11.543
#  DM2 P-V in volts: 12.071
# RMS surface of DM1 = 1.0 nm
# RMS surface of DM2 = 1.0 nm
# [Getting updated summed image]	Elapsed: 14.413442134857178
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/hlc_band1_perfect_bw0.1_r_design_snippet.pkl
# done.
# Itr:  0
# Prev and New Measured Normalized Intensity:			 1.75e-05	->	1.44e-06	 (12.11 x smaller)
#
#
# Iteration: 1 / 4
# DMs to be used in this iteration = [ 1 2 ]
# Core throughput within the half-max isophote(s) = 4.63% 	at separation = (7.0, 0.0) lambda0/D.
# Zernike modes (Noll indexing) used in this Jacobian:	[1]
# Computing control Jacobian matrices in serial:
#   mode0dm1...mode0dm2...done.
# Elapsed: 34.398908615112305
# Using the Jacobian to make other matrices...done.
# Control beginning ...
# Scaling factor:	1.00		1.00		1.00		1.00		1.00		1.00		1.00		1.00
# log10reg:    	-6.0		-5.5		-5.0		-4.5		-4.0		-3.5		-3.0		-2.5
# Inorm:       	3.73e-07	8.31e-08	1.98e-08	7.32e-09	4.23e-09	3.22e-09	3.43e-09	4.91e-09
# Model-based grid search expects log10reg, = -3.5,	 dmfac = 1.00,	 3.22e-09 normalized intensity.
#  DM1 P-V in volts: 12.364
#  DM2 P-V in volts: 10.490
# RMS surface of DM1 = 1.0 nm
# RMS surface of DM2 = 1.0 nm
# [Getting updated summed image]	Elapsed: 14.0672025680542
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/hlc_band1_perfect_bw0.1_r_design_snippet.pkl
# done.
# Itr:  1
# Prev and New Measured Normalized Intensity:			 1.44e-06	->	1.87e-07	 (7.72 x smaller)
#
#
# Iteration: 2 / 4
# DMs to be used in this iteration = [ 1 2 ]
# Core throughput within the half-max isophote(s) = 4.62% 	at separation = (7.0, 0.0) lambda0/D.
# Zernike modes (Noll indexing) used in this Jacobian:	[1]
# Computing control Jacobian matrices in serial:
#   mode0dm1...mode0dm2...done.
# Elapsed: 35.66131067276001
# Using the Jacobian to make other matrices...done.
# Control beginning ...
# Scaling factor:	1.00		1.00		1.00		1.00		1.00		1.00		1.00		1.00
# log10reg:    	-6.0		-5.5		-5.0		-4.5		-4.0		-3.5		-3.0		-2.5
# Inorm:       	3.19e-08	8.16e-09	2.52e-09	1.10e-09	6.57e-10	6.19e-10	8.37e-10	1.33e-09
# Model-based grid search expects log10reg, = -3.5,	 dmfac = 1.00,	 6.19e-10 normalized intensity.
#  DM1 P-V in volts: 11.207
#  DM2 P-V in volts: 9.867
# RMS surface of DM1 = 1.0 nm
# RMS surface of DM2 = 1.0 nm
# [Getting updated summed image]	Elapsed: 14.479283094406128
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/hlc_band1_perfect_bw0.1_r_design_snippet.pkl
# done.
# Itr:  2
# Prev and New Measured Normalized Intensity:			 1.87e-07	->	4.21e-08	 (4.44 x smaller)
#
#
# Iteration: 3 / 4
# DMs to be used in this iteration = [ 1 2 ]
# Core throughput within the half-max isophote(s) = 4.63% 	at separation = (7.0, 0.0) lambda0/D.
# Zernike modes (Noll indexing) used in this Jacobian:	[1]
# Computing control Jacobian matrices in serial:
#   mode0dm1...mode0dm2...done.
# Elapsed: 34.437870502471924
# Using the Jacobian to make other matrices...done.
# Control beginning ...
# Scaling factor:	1.00		1.00		1.00		1.00		1.00		1.00		1.00		1.00
# log10reg:    	-6.0		-5.5		-5.0		-4.5		-4.0		-3.5		-3.0		-2.5
# Inorm:       	1.44e-08	2.78e-09	5.95e-10	2.68e-10	2.38e-10	2.79e-10	3.62e-10	4.76e-10
# Model-based grid search expects log10reg, = -4.0,	 dmfac = 1.00,	 2.38e-10 normalized intensity.
#  DM1 P-V in volts: 11.208
#  DM2 P-V in volts: 10.959
# RMS surface of DM1 = 1.0 nm
# RMS surface of DM2 = 1.0 nm
# [Getting updated summed image]	Elapsed: 14.435762166976929
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/hlc_band1_perfect_bw0.1_r_design_snippet.pkl
# done.
# Itr:  3
# Prev and New Measured Normalized Intensity:			 4.21e-08	->	1.11e-08	 (3.78 x smaller)
#
#
# Iteration: 4 / 4
# DMs to be used in this iteration = [ 1 2 ]
# Core throughput within the half-max isophote(s) = 4.64% 	at separation = (7.0, 0.0) lambda0/D.
# Zernike modes (Noll indexing) used in this Jacobian:	[1]
# Computing control Jacobian matrices in serial:
#   mode0dm1...mode0dm2...done.
# Elapsed: 34.63500952720642
# Using the Jacobian to make other matrices...done.
# Control beginning ...
# Scaling factor:	1.00		1.00		1.00		1.00		1.00		1.00		1.00		1.00
# log10reg:    	-6.0		-5.5		-5.0		-4.5		-4.0		-3.5		-3.0		-2.5
# Inorm:       	7.86e-09	1.15e-09	2.32e-10	1.36e-10	1.41e-10	1.59e-10	1.81e-10	2.06e-10
# Model-based grid search expects log10reg, = -4.5,	 dmfac = 1.00,	 1.36e-10 normalized intensity.
#  DM1 P-V in volts: 11.537
#  DM2 P-V in volts: 12.261
# RMS surface of DM1 = 1.0 nm
# RMS surface of DM2 = 1.0 nm
# [Getting updated summed image]	Elapsed: 14.194695711135864
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/hlc_band1_perfect_bw0.1_r_design_snippet.pkl
# done.
# Itr:  4
# Prev and New Measured Normalized Intensity:			 1.11e-08	->	4.14e-09	 (2.69 x smaller)
#
#
# Core throughput within the half-max isophote(s) = 4.61% 	at separation = (7.0, 0.0) lambda0/D.
#
# Saving abridged workspace to this file:
# 	/home/u21/kianmilani/src/pyfalco/data/brief/hlc_band1_perfect_bw0.1_r_design_snippet.pkl
# done.
#
# Entire workspace NOT saved because mp.flagSaveWS==False
# *** END OF WFSC LOOP ***

# %%
# Load results and plot the output data from pickled data
output_fname = output_dir/(mp.runLabel+'_snippet.pkl')
falco.plot.plot_trial_output_from_pickle(str(output_fname))
